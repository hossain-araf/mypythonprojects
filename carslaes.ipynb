# %%
import pandas as pd
from sklearn.tree import DecisionTreeClassifier
df=pd.read_csv('Car_sales.csv')
df.dtypes
dg=df.drop(columns=['Manufacturer','Sales_in_thousands','__year_resale_value','Latest_Launch','Power_perf_factor','Vehicle_type','Price_in_thousands'])
h=dg.drop(columns=['Horsepower','Wheelbase','Width','Length','Curb_weight','Engine_size'])
h.Fuel_capacity=h.Fuel_capacity.astype('float')
h.Fuel_efficiency=h.Fuel_efficiency.astype('float')
x=h.drop(columns=['Model'])
y=h.Model
model=DecisionTreeClassifier()
model.fit(x,y)
car=model.predict([[13,23],[16,23]])
car
# Out:
# array(['LW', 'Tacoma'], dtype=object)

# %%
h
# Out:
#        Model  Fuel_capacity  Fuel_efficiency
# 0    Integra           13.2             28.0
# 1         TL           17.2             25.0
# 2         CL           17.2             26.0
# 3         RL           18.0             22.0
# 4         A4           16.4             27.0
# ..       ...            ...              ...
# 152      V40           15.8             25.0
# 153      S70           17.9             25.0
# 154      V70           17.9             25.0
# 155      C70           18.5             23.0
# 156      S80           21.1             24.0
#
# [157 rows x 3 columns]

# %%
df.head(123)
# Out:
#     Manufacturer       Model  Sales_in_thousands  __year_resale_value  \
# 0          Acura     Integra              16.919               16.360
# 1          Acura          TL              39.384               19.875
# 2          Acura          CL              14.114               18.225
# 3          Acura          RL               8.588               29.725
# 4           Audi          A4              20.397               22.255
# ..           ...         ...                 ...                  ...
# 118      Pontiac     Sunfire              51.645               13.790
# 119      Pontiac    Grand Am             131.097               10.290
# 120      Pontiac    Firebird              19.911               17.805
# 121      Pontiac  Grand Prix              92.364               14.010
# 122      Pontiac  Bonneville              35.945               13.225
#
#     Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# ...
